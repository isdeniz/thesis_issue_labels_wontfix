# %%
import requests
import pandas as pd
from datetime import datetime
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
access_token='xxx' 
headers = {'Authorization':"Token "+access_token}

# %%
# loop through all pages to obtain all issues information
# label story point = 1
page_num = 1
issues_l=[]
for page_num in range(1,30):
    try:
        # to find all the repos' names from each page
        url = f"https://api.github.com/search/issues?q=is:issue+archived:false+is:public+label:wontfix&page={page_num}"
        issue_l=requests.get(url,headers=headers).json()
        issue_l2=issue_l['items']
        issues_l.append(issue_l2)
    except:
        issues_l.append(None)

# %%
repository=[]
for page in issues_l:
    for issue_l2 in page:
        try:
            repository.append(issue_l2['repository_url'])
        except:
            pass

len(repository)
# Out:
# 870

# %%
#repository

# %%
repository_data=pd.DataFrame()
repository_data['repo_url']=repository

# %%
repository_data
# Out:
#                                               repo_url
# 0    https://api.github.com/repos/ba-archive/blue-a...
# 1    https://api.github.com/repos/typescript-eslint...
# 2     https://api.github.com/repos/localsend/localsend
# 3    https://api.github.com/repos/pauloalbert/zelda...
# 4    https://api.github.com/repos/ouhenio/text-guid...
# ..                                                 ...
# 865  https://api.github.com/repos/zhang-wangz/LeetC...
# 866  https://api.github.com/repos/spring-projects-e...
# 867  https://api.github.com/repos/pmachapman/GoTo.B...
# 868          https://api.github.com/repos/frc6506/docs
# 869           https://api.github.com/repos/waic/wcag21
#
# [870 rows x 1 columns]

# %%
repository_data.iloc[0]
# Out:
# repo_url    https://api.github.com/repos/ba-archive/blue-a...
# Name: 0, dtype: object

# %%
repository_data_name = repository_data["repo_url"].str.split("/", n = 4, expand = True)
repository_data_name
# Out:
#           0 1                2      3  \
# 0    https:     api.github.com  repos
# 1    https:     api.github.com  repos
# 2    https:     api.github.com  repos
# 3    https:     api.github.com  repos
# 4    https:     api.github.com  repos
# ..      ... ..             ...    ...
# 865  https:     api.github.com  repos
# 866  https:     api.github.com  repos
# 867  https:     api.github.com  repos
# 868  https:     api.github.com  repos
# 869  https:     api.github.com  repos
#
#                                                      4
# 0                 ba-archive/blue-archive-story-viewer
# 1                  typescript-eslint/typescript-eslint
# 2                                  localsend/localsend
# 3                           pauloalbert/zelda-datapack
# 4         ouhenio/text-guided-diffusion-style-transfer
# ..                                                 ...
# 865                         zhang-wangz/LeetCodeRating
# 866  spring-projects-experimental/spring-boot-migrator
# 867                              pmachapman/GoTo.Bible
# 868                                       frc6506/docs
# 869                                        waic/wcag21
#
# [870 rows x 5 columns]

# %%
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name = repository_data_name.drop_duplicates()
repository_data_name
# Out:
#                                                      4
# 0                 ba-archive/blue-archive-story-viewer
# 1                  typescript-eslint/typescript-eslint
# 2                                  localsend/localsend
# 3                           pauloalbert/zelda-datapack
# 4         ouhenio/text-guided-diffusion-style-transfer
# ..                                                 ...
# 862                          frc6506/frc6506.github.io
# 865                         zhang-wangz/LeetCodeRating
# 866  spring-projects-experimental/spring-boot-migrator
# 867                              pmachapman/GoTo.Bible
# 868                                       frc6506/docs
#
# [632 rows x 1 columns]

# %%
# loop through all pages to obtain all issues information
issues=[]
for page_num in range(1,3):
    for r in range(repository_data_name.shape[0]):
        repository_i = repository_data_name.iloc[r,0]
        try:
            # to find all the repos' names from each page
            url = f"https://api.github.com/repos/{repository_i}/issues?state=all&page={page_num}"
            issue=requests.get(url,headers=headers).json()
            issues.append(issue)
        except:
            issues.append(None)

# %%
repo_url=[]
for page in issues:
    for issue in page:
        try:
            repo_url.append(issue['repository_url'])
        except:
            pass
len(repo_url)
# Out:
# 25734

# %%
issue_number=[]
for page in issues:
    for issue in page:
        try:
            issue_number.append(issue['number'])
        except:
            pass
len(issue_number)
# Out:
# 25734

# %%
issue_title=[]
for page in issues:
    for issue in page:
        try:
            issue_title.append(issue['title'])
        except:
            pass
len(issue_title)
# Out:
# 25734

# %%
issue_body=[]
for page in issues:
    for issue in page:
        try:
            issue_body.append(issue['body'])
        except:
            pass
len(issue_body)
# Out:
# 25734

# %%
issue_state=[]
for page in issues:
    for issue in page:
        try:
            issue_state.append(issue['state'])
        except:
            pass
len(issue_state)
# Out:
# 25734

# %%
issue_create_time=[]
for page in issues:
    for issue in page:
        try:
            issue_create_time.append(issue['created_at'])
        except:
            pass
len(issue_create_time)
# Out:
# 25734

# %%
issue_update_time=[]
for page in issues:
    for issue in page:
        try:
            issue_update_time.append(issue['updated_at'])
        except:
            pass
len(issue_update_time)
# Out:
# 25734

# %%
issue_close_time=[]
for page in issues:
    for issue in page:
        try:
            issue_close_time.append(issue['closed_at'])
        except:
            pass
len(issue_close_time)
# Out:
# 25734

# %%
issue_pull_request=[]
for page in issues:
    for issue in page:
        try:
            issue_pull_request.append(issue['pull_request'])
        except:
            issue_pull_request.append('not_pull_request')
len(issue_pull_request)
# Out:
# 25734

# %%
issue_label=[]
for page in issues:
    for issue in page:
        try:
            issue_label.append(issue['labels'])
        except:
            pass
len(issue_label)
# Out:
# 25734

# %%
issue_data=pd.DataFrame()
issue_data['repo_url']=repo_url
issue_data['issue_number']=issue_number
issue_data['issue_title']=issue_title
issue_data['issue_body']=issue_body
issue_data['issue_state']=issue_state
issue_data['issue_created_at']=issue_create_time
issue_data['issue_created_at_timestamp']=issue_create_time
issue_data['issue_updated_at']=issue_update_time
issue_data['issue_updated_at_timestamp']=issue_update_time
issue_data['issue_closed_at']=issue_close_time
issue_data['issue_closed_at_timestamp']=issue_close_time
issue_data['resolution_time']=np.nan
issue_data['issue_pull_request']=issue_pull_request
issue_data['issue_label']=issue_label
issue_data['issue_label_name']=issue_label
issue_data=issue_data.reset_index().drop(columns='index')

# %%
issue_data
# Out:
#                                                 repo_url  issue_number  \
# 0      https://api.github.com/repos/ba-archive/blue-a...           179
# 1      https://api.github.com/repos/ba-archive/blue-a...           178
# 2      https://api.github.com/repos/ba-archive/blue-a...           177
# 3      https://api.github.com/repos/ba-archive/blue-a...           176
# 4      https://api.github.com/repos/ba-archive/blue-a...           175
# ...                                                  ...           ...
# 25729          https://api.github.com/repos/frc6506/docs            99
# 25730          https://api.github.com/repos/frc6506/docs            98
# 25731          https://api.github.com/repos/frc6506/docs            97
# 25732          https://api.github.com/repos/frc6506/docs            96
# 25733          https://api.github.com/repos/frc6506/docs            95
#
#                                  issue_title  \
# 0                     [Enhancement] i18n修正zh
# 1                                  后端功能支持讨论区
# 2                         [Bug] 剧情详情的标题无i18n
# 3                 [Bug] 润色后的momotalk和剧情又不一样了
# 4                  [Enhancement] 支持全学生回忆大厅浏览
# ...                                      ...
# 25729           Link to cheat sheet in index
# 25730                       Cheat sheet patc
# 25731                       Added some stuff
# 25732                    Updates for class 1
# 25733  update to 2021-22 GitHub Presentation
#
#                                               issue_body issue_state  \
# 0      ### 功能描述\n\n_作为一个中国人，不应该刻意把湾湾独立\r\ncn和tw是一体！_\...      closed
# 1      - 根据文字搜索对应剧情并跳转，player dev 分支已经实现自由跳转\r\n- 接入 ...        open
# 2      ### 问题描述\n\n\r\n![image](https://user-images.g...        open
# 3      ### 问题描述\n\n![image](https://user-images.githu...        open
# 4      ### 功能描述\n\n- 新开导航tab, 在该页面可以选中学生的回忆大厅进行浏览, \r...        open
# ...                                                  ...         ...
# 25729                                               None      closed
# 25730                                               None      closed
# 25731                                               test        open
# 25732                                               None      closed
# 25733  https://docs.google.com/presentation/d/1C4kl43...      closed
#
#            issue_created_at issue_created_at_timestamp      issue_updated_at  \
# 0      2023-03-12T08:39:41Z       2023-03-12T08:39:41Z  2023-03-12T08:51:26Z
# 1      2023-03-12T08:37:04Z       2023-03-12T08:37:04Z  2023-03-12T08:39:49Z
# 2      2023-03-12T06:51:22Z       2023-03-12T06:51:22Z  2023-03-12T08:28:18Z
# 3      2023-03-11T18:29:40Z       2023-03-11T18:29:40Z  2023-03-12T08:28:31Z
# 4      2023-03-11T15:15:43Z       2023-03-11T15:15:43Z  2023-03-11T15:15:53Z
# ...                     ...                        ...                   ...
# 25729  2021-11-04T06:06:20Z       2021-11-04T06:06:20Z  2021-11-19T00:10:41Z
# 25730  2021-11-04T05:42:46Z       2021-11-04T05:42:46Z  2021-11-19T00:12:02Z
# 25731  2021-11-01T00:41:07Z       2021-11-01T00:41:07Z  2021-11-01T00:41:07Z
# 25732  2021-10-31T21:53:03Z       2021-10-31T21:53:03Z  2021-11-19T00:12:25Z
# 25733  2021-10-31T19:06:06Z       2021-10-31T19:06:06Z  2022-03-13T02:51:58Z
#
#       issue_updated_at_timestamp       issue_closed_at  \
# 0           2023-03-12T08:51:26Z  2023-03-12T08:51:26Z
# 1           2023-03-12T08:39:49Z                  None
# 2           2023-03-12T08:28:18Z                  None
# 3           2023-03-12T08:28:31Z                  None
# 4           2023-03-11T15:15:53Z                  None
# ...                          ...                   ...
# 25729       2021-11-19T00:10:41Z  2021-11-18T09:51:57Z
# 25730       2021-11-19T00:12:02Z  2021-11-04T06:00:32Z
# 25731       2021-11-01T00:41:07Z                  None
# 25732       2021-11-19T00:12:25Z  2021-10-31T21:58:15Z
# 25733       2022-03-13T02:51:58Z  2022-03-13T02:51:49Z
#
#       issue_closed_at_timestamp  resolution_time  \
# 0          2023-03-12T08:51:26Z              NaN
# 1                          None              NaN
# 2                          None              NaN
# 3                          None              NaN
# 4                          None              NaN
# ...                         ...              ...
# 25729      2021-11-18T09:51:57Z              NaN
# 25730      2021-11-04T06:00:32Z              NaN
# 25731                      None              NaN
# 25732      2021-10-31T21:58:15Z              NaN
# 25733      2022-03-13T02:51:49Z              NaN
#
#                                       issue_pull_request  \
# 0                                       not_pull_request
# 1                                       not_pull_request
# 2                                       not_pull_request
# 3                                       not_pull_request
# 4                                       not_pull_request
# ...                                                  ...
# 25729                                   not_pull_request
# 25730  {'url': 'https://api.github.com/repos/frc6506/...
# 25731  {'url': 'https://api.github.com/repos/frc6506/...
# 25732  {'url': 'https://api.github.com/repos/frc6506/...
# 25733                                   not_pull_request
#
#                                              issue_label  \
# 0      [{'id': 4592253969, 'node_id': 'LA_kwDOIF9jcs8...
# 1      [{'id': 4592253967, 'node_id': 'LA_kwDOIF9jcs8...
# 2      [{'id': 4592253966, 'node_id': 'LA_kwDOIF9jcs8...
# 3      [{'id': 4592253966, 'node_id': 'LA_kwDOIF9jcs8...
# 4      [{'id': 4592253969, 'node_id': 'LA_kwDOIF9jcs8...
# ...                                                  ...
# 25729  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25730  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25731                                                 []
# 25732  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25733  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
#
#                                         issue_label_name
# 0      [{'id': 4592253969, 'node_id': 'LA_kwDOIF9jcs8...
# 1      [{'id': 4592253967, 'node_id': 'LA_kwDOIF9jcs8...
# 2      [{'id': 4592253966, 'node_id': 'LA_kwDOIF9jcs8...
# 3      [{'id': 4592253966, 'node_id': 'LA_kwDOIF9jcs8...
# 4      [{'id': 4592253969, 'node_id': 'LA_kwDOIF9jcs8...
# ...                                                  ...
# 25729  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25730  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25731                                                 []
# 25732  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25733  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
#
# [25734 rows x 15 columns]

# %%
j = 0
for j in range(issue_data.shape[0]):
    issue_data.iloc[j,6] = datetime.strptime(issue_data.iloc[j,5], '%Y-%m-%dT%H:%M:%SZ')
    issue_data.iloc[j,8] = datetime.strptime(issue_data.iloc[j,7], '%Y-%m-%dT%H:%M:%SZ')
    if issue_data.iloc[j,4] == 'closed':
        issue_data.iloc[j,10] = datetime.strptime(issue_data.iloc[j,9], '%Y-%m-%dT%H:%M:%SZ')

# %%
j = 0
for j in range(issue_data.shape[0]):
    if len(issue_data.iloc[j,13]) == 0:
        issue_data.iloc[j,14] = 'no_label'
    else:
        multi_labels = []
        k = 0
        label1 = issue_data.iloc[j,13]
        for k in range(len(issue_data.iloc[j,14])):
            x = label1[k]['name']
            multi_labels += [x]
            # print(multi_labels)
            # print(k)
        issue_data.iloc[j,14] = str(multi_labels)

# %%
j = 0
for j in range(issue_data.shape[0]):
    if issue_data.iloc[j,12] != 'not_pull_request': 
        issue_data.iloc[j,12] = 'pull_request'

# %%
issue_data.to_excel('label_wontfix_issues.xlsx')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1184: UserWarning: Ignoring URL 'https://github.com/invertase/dart_custom_lint/issues/113
#
# **Describe%20the%20bug**
# When%20the%20dart%20analyzer%20is%20started,%20I%20get%20an%20error%20in%20custom_lint.log.
#
# EDIT:%20I%20am%20on%200.3.2%20of%20%60custom_lint%60.
#
# %60%60%60
# The%20Dart%20VM%20service%20is%20listening%20on%20http://127.0.0.1:1421/dKDOdS3hIVo=/
# The%20Dart%20DevTools%20debugger%20and%20profiler%20is%20available%20at:%20http://127.0.0.1:1421/dKDOdS3hIVo=/devtools/' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn("Ignoring URL '%s' with link or location/anchor > %d "
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1184: UserWarning: Ignoring URL 'https://spex.zazuko.com/' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn("Ignoring URL '%s' with link or location/anchor > %d "

# %%
issue_data_closed = issue_data.dropna(subset = ['issue_closed_at'])

# %%
j = 0
for j in range(issue_data_closed.shape[0]):
    issue_data_closed.iloc[j,11] = ((issue_data_closed.iloc[j,10] - issue_data_closed.iloc[j,6]).total_seconds())/(24*60*60)

# %%
issue_data_closed.to_excel('label_wontfix_issues_closed.xlsx')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xlsxwriter/worksheet.py:1184: UserWarning: Ignoring URL 'https://github.com/invertase/dart_custom_lint/issues/113
#
# **Describe%20the%20bug**
# When%20the%20dart%20analyzer%20is%20started,%20I%20get%20an%20error%20in%20custom_lint.log.
#
# EDIT:%20I%20am%20on%200.3.2%20of%20%60custom_lint%60.
#
# %60%60%60
# The%20Dart%20VM%20service%20is%20listening%20on%20http://127.0.0.1:1421/dKDOdS3hIVo=/
# The%20Dart%20DevTools%20debugger%20and%20profiler%20is%20available%20at:%20http://127.0.0.1:1421/dKDOdS3hIVo=/devtools/' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn("Ignoring URL '%s' with link or location/anchor > %d "

# %%
issue_data_closed
# Out:
#                                                 repo_url  issue_number  \
# 0      https://api.github.com/repos/ba-archive/blue-a...           179
# 6      https://api.github.com/repos/ba-archive/blue-a...           173
# 7      https://api.github.com/repos/ba-archive/blue-a...           172
# 11     https://api.github.com/repos/ba-archive/blue-a...           168
# 12     https://api.github.com/repos/ba-archive/blue-a...           167
# ...                                                  ...           ...
# 25728          https://api.github.com/repos/frc6506/docs           100
# 25729          https://api.github.com/repos/frc6506/docs            99
# 25730          https://api.github.com/repos/frc6506/docs            98
# 25732          https://api.github.com/repos/frc6506/docs            96
# 25733          https://api.github.com/repos/frc6506/docs            95
#
#                                              issue_title  \
# 0                                 [Enhancement] i18n修正zh
# 6      chore(deps): update dependency @pixi/filter-ad...
# 7      chore(deps): update dependency @pixi/extension...
# 11                               [Bug] 浏览器momotalk对话历史丢失
# 12     chore(deps): update dependency @pixi/display t...
# ...                                                  ...
# 25728                                      Cheat sheet 2
# 25729                       Link to cheat sheet in index
# 25730                                   Cheat sheet patc
# 25732                                Updates for class 1
# 25733              update to 2021-22 GitHub Presentation
#
#                                               issue_body issue_state  \
# 0      ### 功能描述\n\n_作为一个中国人，不应该刻意把湾湾独立\r\ncn和tw是一体！_\...      closed
# 6      [![Mend Renovate](https://app.renovatebot.com/...      closed
# 7      [![Mend Renovate](https://app.renovatebot.com/...      closed
# 11     ### 问题描述\r\n\r\n浏览器（不安装应用）播放剧情再切回来\r\nmomotalk...      closed
# 12     [![Mend Renovate](https://app.renovatebot.com/...      closed
# ...                                                  ...         ...
# 25728                Lots of updates\r\nAlso closes #99       closed
# 25729                                               None      closed
# 25730                                               None      closed
# 25732                                               None      closed
# 25733  https://docs.google.com/presentation/d/1C4kl43...      closed
#
#            issue_created_at issue_created_at_timestamp      issue_updated_at  \
# 0      2023-03-12T08:39:41Z        2023-03-12 08:39:41  2023-03-12T08:51:26Z
# 6      2023-03-11T14:45:59Z        2023-03-11 14:45:59  2023-03-12T08:43:57Z
# 7      2023-03-11T14:44:40Z        2023-03-11 14:44:40  2023-03-12T08:43:55Z
# 11     2023-03-11T12:00:12Z        2023-03-11 12:00:12  2023-03-11T13:06:13Z
# 12     2023-03-11T11:42:19Z        2023-03-11 11:42:19  2023-03-12T08:43:53Z
# ...                     ...                        ...                   ...
# 25728  2021-11-18T09:39:19Z        2021-11-18 09:39:19  2021-11-19T00:11:48Z
# 25729  2021-11-04T06:06:20Z        2021-11-04 06:06:20  2021-11-19T00:10:41Z
# 25730  2021-11-04T05:42:46Z        2021-11-04 05:42:46  2021-11-19T00:12:02Z
# 25732  2021-10-31T21:53:03Z        2021-10-31 21:53:03  2021-11-19T00:12:25Z
# 25733  2021-10-31T19:06:06Z        2021-10-31 19:06:06  2022-03-13T02:51:58Z
#
#       issue_updated_at_timestamp       issue_closed_at  \
# 0            2023-03-12 08:51:26  2023-03-12T08:51:26Z
# 6            2023-03-12 08:43:57  2023-03-12T08:43:26Z
# 7            2023-03-12 08:43:55  2023-03-12T08:43:25Z
# 11           2023-03-11 13:06:13  2023-03-11T12:40:32Z
# 12           2023-03-12 08:43:53  2023-03-12T08:43:24Z
# ...                          ...                   ...
# 25728        2021-11-19 00:11:48  2021-11-18T09:51:57Z
# 25729        2021-11-19 00:10:41  2021-11-18T09:51:57Z
# 25730        2021-11-19 00:12:02  2021-11-04T06:00:32Z
# 25732        2021-11-19 00:12:25  2021-10-31T21:58:15Z
# 25733        2022-03-13 02:51:58  2022-03-13T02:51:49Z
#
#       issue_closed_at_timestamp  resolution_time issue_pull_request  \
# 0           2023-03-12 08:51:26         0.008160   not_pull_request
# 6           2023-03-12 08:43:26         0.748229       pull_request
# 7           2023-03-12 08:43:25         0.749132       pull_request
# 11          2023-03-11 12:40:32         0.028009   not_pull_request
# 12          2023-03-12 08:43:24         0.875752       pull_request
# ...                         ...              ...                ...
# 25728       2021-11-18 09:51:57         0.008773       pull_request
# 25729       2021-11-18 09:51:57        14.156678   not_pull_request
# 25730       2021-11-04 06:00:32         0.012338       pull_request
# 25732       2021-10-31 21:58:15         0.003611       pull_request
# 25733       2022-03-13 02:51:49       132.323414   not_pull_request
#
#                                              issue_label  \
# 0      [{'id': 4592253969, 'node_id': 'LA_kwDOIF9jcs8...
# 6                                                     []
# 7                                                     []
# 11     [{'id': 4592253969, 'node_id': 'LA_kwDOIF9jcs8...
# 12                                                    []
# ...                                                  ...
# 25728  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25729  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25730  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25732  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
# 25733  [{'id': 1892940948, 'node_id': 'MDU6TGFiZWwxOD...
#
#                                         issue_label_name
# 0                             ['enhancement', 'wontfix']
# 6                                               no_label
# 7                                               no_label
# 11          ['enhancement', 'module: momotalk', 'fixed']
# 12                                              no_label
# ...                                                  ...
# 25728                        ['enhancement', 'doc-Java']
# 25729    ['enhancement', 'good first issue', 'doc-Java']
# 25730          ['enhancement', 'experiment', 'doc-Java']
# 25732  ['enhancement', 'doc-GitHub', 'doc-Java', 'doc...
# 25733  ['enhancement', 'good first issue', 'invalid',...
#
# [19646 rows x 15 columns]
